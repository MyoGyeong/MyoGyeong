# %% [markdown]
# <a href="https://colab.research.google.com/github/MyoGyeong/MyoGyeong/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 라이브러리 가져오기
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

tf.compat.v1.disable_eager_execution()
import tensorflow_hub as hub
import os

# 데이터 로드
for dir_name, _, filenames in os.walk('/content/drive/MyDrive/dataset_insect'):
    for filenames in filenames:
        print(os.path.join(dir_name, filenames))

data_dir = '/content/drive/MyDrive/dataset_insect'
train_dir = '/content/drive/MyDrive/dataset_insect/train'
test_dir = '/content/drive/MyDrive/dataset_insect/test'

# 레이블 매핑
import json

with open('/content/drive/MyDrive/categories1.json', 'r') as f:
    cat_to_name = json.load(f)
    classes = list(cat_to_name.values())

print(classes)

# tensorflow 허브를 사용한 전이 학습
module_selection = ("inception_v3", 224, 1280)
handle_base, pixels, FV_SIZE = module_selection
MODULE_HANDLE ="https://tfhub.dev/google/tf2-preview/{}/feature_vector/2".format(handle_base)
IMAGE_SIZE = (pixels, pixels)
print("Using {} with input size {} and output dimension {}".format(
  MODULE_HANDLE, IMAGE_SIZE, FV_SIZE))
BATCH_SIZE =  32#@param {type:"integer"}

# 데이터 전처리
# Inputs are suitably resized for the selected module.
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1. / 255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    shuffle=False,
    seed=42,
    color_mode="rgb",
    class_mode="categorical",
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE)
do_data_augmentation = True  # @param {type:"boolean"}
if do_data_augmentation:
    train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
        rescale=1. / 255,
        rotation_range=40,
        horizontal_flip=True,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        fill_mode='nearest')
else:
    train_datagen = test_datagen

train_generator = train_datagen.flow_from_directory(
    train_dir,
    subset="training",
    shuffle=True,
    seed=42,
    color_mode="rgb",
    class_mode="categorical",
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE)

# 모델 빌드
feature_extractor = hub.KerasLayer(MODULE_HANDLE,
                                   input_shape=IMAGE_SIZE + (3,),
                                   output_shape=[FV_SIZE])
do_fine_tuning = False  # @param {type:"boolean"}
if do_fine_tuning:
    feature_extractor.trainable = True
    # unfreeze some layers of base network for fine-tuning
    for layer in feature_extractor.layers[-30:]:
        layer.trainable = True

else:
    feature_extractor.trainable = False

print("Building model with", MODULE_HANDLE)
model = tf.keras.Sequential([
    feature_extractor,
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(train_generator.num_classes, activation='softmax',
                          kernel_regularizer=tf.keras.regularizers.l2(0.0001))
])
'''

'''
model.summary()

# 손실 함수와 옵티마이저 지정
# Compile model specifying the optimizer learning rate
LEARNING_RATE = 0.01 #@param {type:"number"}
model.compile(
   optimizer=tf.keras.optimizers.Adam(lr=LEARNING_RATE),
   loss='categorical_crossentropy',
   metrics=['accuracy'])
# Out:
# /content/drive/MyDrive/dataset_insect/test/medinalis/2.jpg
# /content/drive/MyDrive/dataset_insect/test/medinalis/4.jpg
# /content/drive/MyDrive/dataset_insect/test/medinalis/8.jpg
# /content/drive/MyDrive/dataset_insect/test/medinalis/12.jpg
# /content/drive/MyDrive/dataset_insect/test/medinalis/22.jpg
# /content/drive/MyDrive/dataset_insect/test/medinalis/25.jpg
# /content/drive/MyDrive/dataset_insect/test/medinalis/30.jpg
# /content/drive/MyDrive/dataset_insect/test/medinalis/43.jpg
# /content/drive/MyDrive/dataset_insect/test/medinalis/48.jpg
# /content/drive/MyDrive/dataset_insect/test/medinalis/49.jpg
# /content/drive/MyDrive/dataset_insect/test/leafhopper/1.jpg
# /content/drive/MyDrive/dataset_insect/test/leafhopper/5.jpg
# /content/drive/MyDrive/dataset_insect/test/leafhopper/15.jpg
# /content/drive/MyDrive/dataset_insect/test/leafhopper/18.jpg
# /content/drive/MyDrive/dataset_insect/test/leafhopper/20.jpg
# /content/drive/MyDrive/dataset_insect/test/leafhopper/36.png
# ...

# %%
# 훈련 모델
EPOCHS=30 #@param {type:"integer"}
history = model.fit_generator(
        train_generator,
        steps_per_epoch=train_generator.samples//train_generator.batch_size,
        epochs=EPOCHS,
        validation_data=test_generator,
        validation_steps=test_generator.samples//test_generator.batch_size)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: `model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   if __name__ == '__main__':
# 42/42 [==============================] - ETA: 0s - batch: 20.5000 - size: 31.5000 - loss: 7.6980 - accuracy: 0.4649
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 42/42 [==============================] - 530s 12s/step - batch: 20.5000 - size: 31.5000 - loss: 7.6879 - accuracy: 0.4649 - val_loss: 0.8240 - val_accuracy: 0.6250
# Epoch 2/30
# 42/42 [==============================] - 184s 4s/step - batch: 20.5000 - size: 31.5000 - loss: 0.8265 - accuracy: 0.7105 - val_loss: 0.6463 - val_accuracy: 0.7188
# Epoch 3/30
# ...

# %%
import matplotlib.pylab as plt
import numpy as np
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(EPOCHS)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.ylabel("Accuracy (training and validation)")
plt.xlabel("Training Steps")
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.ylabel("Loss (training and validation)")
plt.xlabel("Training Steps")
plt.show()

# %%
import cv2
import itertools
import random
from collections import Counter
from glob import iglob
def load_image(filename):
  img = cv2.imread(os.path.join(data_dir, test_dir, filename))
  img = cv2.resize(img,(IMAGE_SIZE[0], IMAGE_SIZE[1]))
  img=img/255
  return img

def predict(image):
  probabilities = model.predict(np.asarray([img]))[0]
  class_idx = np.argmax(probabilities)
  return {classes[class_idx]: probabilities[class_idx]}
for idx, filename in enumerate(random.sample(test_generator.filenames, 5)):
    print("SOURCE: class: %s, file: %s" % (os.path.split(filename)[0], filename))
    
    img = load_image(filename)
    prediction = predict(img)
    print("PREDICTED: class: %s, confidence: %f" % (list(prediction.keys())[0], list(prediction.values())[0]))
    plt.imshow(img)
    plt.figure(idx)    
    plt.show()
# Out:
# SOURCE: class: oryzophilus, file: oryzophilus/48.PNG
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# PREDICTED: class: oryzophilus, confidence: 1.000000
# SOURCE: class: rice_leafminer, file: rice_leafminer/벼잎물가파리10.PNG
# PREDICTED: class: rice_leafminer, confidence: 0.785598
# SOURCE: class: leafhopper, file: leafhopper/38.png
# PREDICTED: class: leafhopper, confidence: 0.999899
# SOURCE: class: small_brown_planthopper, file: small_brown_planthopper/3.jpg
# PREDICTED: class: small_brown_planthopper, confidence: 0.908831
# SOURCE: class: suppressalis, file: suppressalis/41.jpg
# PREDICTED: class: suppressails, confidence: 0.867220

# %%
from keras.utils.vis_utils import plot_model
plot_model(model,to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.save('model_insect.h5')

# %%
#h5파일을 pb파일로 전환
model=tf.keras.models.load_model('./model.h5',compile=False,custom_objects={'KerasLayer': hb.KerasLayer})
export_path='./'
model.save(export_path,save_format="tf")

#pb파일을 tflite파일로 전환

converter = tf.lite.TFLiteConverter.from_saved_model('./')
tflite_model = converter.convert()
open("./my_model.tflite", "wb").write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c4200db643c2> in <module>()
#       1 #h5파일을 pb파일로 전환
# ----> 2 model=tf.keras.models.load_model('./model.h5',compile=False,custom_objects={'KerasLayer': hb.KerasLayer})
#       3 export_path='./'
#       4 model.save(export_path,save_format="tf")
#       5
#
# NameError: name 'hb' is not defined
